# %%
# %pip install pandas numpy matplotlib
# Out:
# Requirement already satisfied: pandas in c:\users\aryman\appdata\local\programs\python\python312\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy in c:\users\aryman\appdata\local\programs\python\python312\lib\site-packages (2.1.2)
# Requirement already satisfied: matplotlib in c:\users\aryman\appdata\local\programs\python\python312\lib\site-packages (3.9.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aryman\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aryman\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aryman\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aryman\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\aryman\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aryman\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aryman\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\aryman\appdata\roaming\python\python312\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\aryman\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aryman\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\aryman\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
np.random.seed(7)

y = np.random.randint(low = 1, high = 1500, size = 10)

# %%
y
# Out:
# array([ 176, 1221,  538,  503,  212,  920, 1373, 1210, 1423,  536],
#       dtype=int32)

# %%
plt.plot(y)

# %%
# inserir a primeira linha no plot
plt.plot(y,color = '#749187', marker = 'o', ms = 5, mec = 'k', markerfacecolor = 'w', ls = '-.')

# inserir a segunda linha no plot
plt.plot(y*2, marker = '+', color = 'black', ms = 5)

# rótulo
plt.xlabel('Eixo X', color = 'red', size = 12)
plt.ylabel('Eixo y', color = 'blue', size = 12)
plt.title('Título', loc = 'center')

#gridlines
plt.grid(axis= 'both', color = 'gray', linestyle = '--', linewidth = 1, alpha = 0.8)
plt.show()

# %%
np.random.seed(6)
x = np.arange(1, 11)
y1 = np.random.randint(1, 400, 10)
y2 = np.random.randint(150, 500, 10)
y3 = np.random.randint(200, 600, 10)

plt.figure(figsize= (15, 5))
plt.suptitle('Figura', fontsize = 15)

plt.subplot(1, 3, 1)
plt.plot(x, y1, color = 'k')
plt.title('Subplot 1', pad = 10)
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')

plt.subplot(1, 3, 2)
plt.plot(x, y2, color = 'r')
plt.title('Subplot 2', pad = 10)
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')

plt.subplot(1, 3, 3)
plt.plot(x, y3, color = 'g')
plt.title('Subplot 3', pad = 10)
plt.xlabel('Eixo X')
plt.ylabel('Eixo Y')

plt.tight_layout(pad = 4)
plt.show()

# %%
fig, ax = plt.subplots(1, 3, figsize = (15, 5))
fig.suptitle('Figure')
ax[0].plot(x, y1, color = 'black')
ax[1].plot(x, y2, color = 'red')
ax[2].plot(x, y3, color = 'green')

for i in range(3):
  ax[i].set(title = f'Subplot {i+1}', xlabel = 'Eixo X', ylabel = 'Eixo Y')

# %%
data = np.random.normal(10, 0.5, 5000)
plt.hist(data)
plt.show()

# %%
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x204fa32ac60>,
#   <matplotlib.lines.Line2D at 0x204fa32af90>],
#  'caps': [<matplotlib.lines.Line2D at 0x204fa32b260>,
#   <matplotlib.lines.Line2D at 0x204fa329d00>],
#  'boxes': [<matplotlib.lines.Line2D at 0x204fa32a990>],
#  'medians': [<matplotlib.lines.Line2D at 0x204fa32b6e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x204fa32b950>],
#  'means': []}

# %%
x = np.random.normal(10, 0.5, 100)
y = np.random.normal(0, 20, 100)

# %%
fig = plt.figure()
ax = plt.axes()
ax.scatter(x, y, marker = 'o', color = 'red', label = 'data 1', alpha= 0.5)
ax.scatter(x*0.5, y*0.5, marker = 'v', color = 'black', label = 'data 2', alpha= 0.7)
ax.legend()

# %%
# %pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\aryman\appdata\local\programs\python\python312\lib\site-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\aryman\appdata\local\programs\python\python312\lib\site-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in c:\users\aryman\appdata\roaming\python\python312\site-packages (from plotly) (24.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px

# %%
px.data.gapminder()
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# 3           4
# 4           4
# ...       ...
# 1699      716
# 1700      716
# 1701      716
# 1702      716
# 1703      716
#
# [1704 rows x 8 columns]

# %%
df = px.data.gapminder().query('country == "Brazil"').set_index('year')

# %%
df.head()
# Out:
#      country continent  lifeExp        pop    gdpPercap iso_alpha  iso_num
# year
# 1952  Brazil  Americas   50.917   56602560  2108.944355       BRA       76
# 1957  Brazil  Americas   53.285   65551171  2487.365989       BRA       76
# 1962  Brazil  Americas   55.665   76039390  3336.585802       BRA       76
# 1967  Brazil  Americas   57.632   88049823  3429.864357       BRA       76
# 1972  Brazil  Americas   59.504  100840058  4985.711467       BRA       76

# %%
plt.plot(df.index, df['gdpPercap'])
plt.title('PIB per capita do Brasil')
plt.ylabel('PIB per capita')
plt.xlabel('Tempo')
# Out:
# Text(0.5, 0, 'Tempo')

# %%
title = 'Relação entre expectativa de vida e renda per capita Brasil'

plt.figure(figsize= (12, 4))
plt.scatter(df['lifeExp'], df['gdpPercap'], cmap= 'viridis')
plt.xlabel('Expectativa de vida')
plt.ylabel('Renda per capita')
plt.title(title, loc = 'left')
plt.show()
# Out:
# C:\Users\Aryman\AppData\Local\Temp\ipykernel_1892\4208402243.py:4: UserWarning:
#
# No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored

# %%
plt.bar(
        x = df.index,
        height=df['pop'],
        color = 'red'
      )
plt.title('População Brasileira')
# Out:
# Text(0.5, 1.0, 'População Brasileira')

# %%
def filtrar_continente(continente):
  df = px.data.gapminder()
  df = df[df['continent'] == continente]
  return df

# %%
def filtrar_pais(pais, variavel):
  'Filtrar algum país da amostra para as variáveis "POP", "gdpPercap", "Lifeexp"'
  df = px.data.gapminder()
  df = df[df['country'] == pais[variavel]]
  return

# %%
americas = filtrar_continente('Americas')
paises = americas['country'].unique()
plt.figure(figsize= (12, 8))

for pais in paises:
  plt.scatter(
    filtrar_pais( pais = pais, variavel= 'lifeExp' ),
    filtrar_pais( pais = pais, variavel= 'gdpPercap' ))

plt.legend(labels = paises, loc = 'best')
plt.title('Relação entre renda per capita e expectativa de vida')
plt.xlabel('Expectativa de vida')
plt.ylabel('Renda per capita')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 7
#       3 plt.figure(figsize= (12, 8))
#       5 for pais in paises:
#       6   plt.scatter(
# ----> 7     filtrar_pais( pais = pais, variavel= 'lifeExp' ),
#       8     filtrar_pais( pais = pais, variavel= 'gdpPercap' ))
#      10 plt.legend(labels = paises, loc = 'best')
#      11 plt.title('Relação entre renda per capita e expectativa de vida')
#
# Cell In[50], line 4, in filtrar_pais(pais, variavel)
#       2 'Filtrar algum país da amostra para as variáveis "POP", "gdpPercap", "Lifeexp"'
#       3 df = px.data.gapminder()
# ----> 4 df = df[df['country'] == pais[variavel]]
#       5 return
#
# TypeError: string indices must be integers, not 'str'
